# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 500)

print("sin curve")
plt.plot(x, np.sin(x))
plt.show()
# Out:
# sin curve

# %% [markdown]
# $$
#   y = sinx
# $$
